# %% [markdown]
# # Import packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import math
from src.langsim_utils import *

# %% [markdown]
# # Import datasets

# %%
# load the WALS dataset
walsdata = pd.read_csv('../datasets/wals/language.csv', sep=',')

# load the languages dataset
nllb_lang = pd.read_csv('../EDA/nllb_languages.csv', sep=';')

# %% [markdown]
# # Data cleaning

# %% [markdown]
# #### Select relevant languages

# %%
llama_lang_wals = ["bul","ctl","cze","dsh", "dut","ger","eng","fin","fre","scr","hun", "ind", "ita","jpn","kor","nor","pol","por","rus", "spa","swe","rom","slo",'tha',"vie","mnd","ukr"]
mgsm_lang = ["eng","fre","spa","ger","jap","rus","swa","tel","tha","ben","mdn"]
nllb_langs = ['ace', 'acm', 'acq', 'aeb', 'afr', 'aka', 'amh', 'arb', 'arb', 'ars', 'ary', 'arz', 'asm', 'ast', 'awa', 'ayr', 'azj', 'bak', 'bam', 'ban', 'bel', 'bem', 'ben', 'bho', 'bjn', 'bjn', 'bos', 'bug', 'bul', 'cat', 'ceb', 'ces', 'cjk', 'ckb', 'crh', 'dan', 'dik', 'dyu', 'dzo', 'eng', 'epo', 'est', 'fao', 'fin','fon', 'fra', 'fur', 'fuv', 'gla', 'glg', 'grn', 'guj', 'hat', 'hau','hin', 'hne', 'hrv', 'hun', 'ibo', 'ilo', 'isl', 'jav', 'jpn', 'kab', 'kac', 'kam', 'kan', 'kas', 'kas', 'kat', 'knc', 'knc','kaz', 'kbp', 'kea','khm', 'kik', 'kin', 'kmb', 'kon', 'kor','lao', 'lij', 'lim', 'lin', 'lit', 'lmo', 'ltg', 'ltz', 'lua', 'lug', 'luo', 'lus', 'lvs', 'mag', 'mai', 'mal', 'mar', 'min', 'min', 'mkd', 'plt','mlt', 'mni', 'khk', 'mos', 'mri', 'mya', 'nno', 'nob', 'npi', 'nso', 'nus', 'nya', 'gaz', 'ory', 'pag', 'pan', 'pap', 'pes', 'pol', 'por', 'prs', 'pbt', 'quy', 'run', 'rus', 'sag', 'san', 'sat', 'scn', 'shn', 'sin', 'slk', 'slv','smo', 'snd', 'som', 'sot', 'als', 'srd', 'srp', 'ssw','sun', 'swh', 'szl', 'tel', 'tgk', 'tgl', 'tha', 'tir', 'taq', 'taq', 'tpi', 'tsn', 'tso', 'tuk', 'tum', 'tur', 'twi', 'uig', 'ukr', 'umb', 'urd', 'vec', 'vie', 'war', 'wol', 'xho', 'yor', 'yue', 'zho', 'zho', 'zsm']
walsdata_test = walsdata.loc[walsdata['iso_code'].isin(nllb_langs)]

walsdata_test2 = walsdata.loc[walsdata['wals_code'].isin(['tvo','tml','shn','bma','uzn','mol','bsq','dut','ewe','ger','heb','iri','ind','ita','spa','swe','tib','zul','ydd','wel','ams','aze','grk','fij','krd','arm','kgz'])]

# %%
walsdata_test = walsdata_test.sort_values(by='iso_code')
walsdata_test = pd.concat([walsdata_test,walsdata_test2])
# Out:
#      wals_code iso_code glottocode                  Name   latitude  \
# 676        fin      fin   finn1318               Finnish  62.000000
# 684        fon      fon   fonn1241                Fongbe   6.416667
# 689        fre      fra   stan1290                French  48.000000
# 681        fni      fuv   nige1253       Fula (Nigerian)   8.166667
# 1868       owc      gaz   west2721  Oromo (West-Central)   9.000000
# ...        ...      ...        ...                   ...        ...
# 1933       por      por   port1283            Portuguese  39.000000
# 618        dri      prs   dari1249                  Dari  35.000000
# 1972       qay      quy   ayac1239    Quechua (Ayacucho) -14.000000
# 2015       rnd      run   rund1242                 Rundi  -3.500000
# 2038       rus      rus   russ1263               Russian  56.000000
#
#       longitude                  genus         family      macroarea  \
# 676   25.000000                 Finnic         Uralic        Eurasia
# 684    2.166667                    Kwa    Niger-Congo         Africa
# 689    2.000000                Romance  Indo-European        Eurasia
# 681   10.500000      Northern Atlantic    Niger-Congo         Africa
# 1868  37.000000  Lowland East Cushitic   Afro-Asiatic         Africa
# ...         ...                    ...            ...            ...
# 1933  -8.000000                Romance  Indo-European        Eurasia
# 618   66.000000                Iranian  Indo-European        Eurasia
# 1972 -74.000000               Quechuan       Quechuan  South America
# 2015  30.000000                Bantoid    Niger-Congo         Africa
# 2038  38.000000                 Slavic  Indo-European        Eurasia
#
#      countrycodes  ...  137B M in Second Person Singular  \
# 676            FI  ...  1 No m in second person singular
# 684            BJ  ...                               NaN
# 689         CH FR  ...  1 No m in second person singular
# 681            NG  ...                               NaN
# 1868           ET  ...                               NaN
# ...           ...  ...                               ...
# 1933           PT  ...                               NaN
# 618            AF  ...                               NaN
# 1972           PE  ...                               NaN
# 2015           BI  ...                               NaN
# 2038           RU  ...  1 No m in second person singular
#
#      136B M in First Person Singular 109B Other Roles of Applied Objects  \
# 676     2 m in first person singular       5 No applicative construction
# 684                              NaN                                 NaN
# 689     2 m in first person singular       5 No applicative construction
# 681                              NaN                                 NaN
# 1868                             NaN                                 NaN
# ...                              ...                                 ...
# 1933                             NaN                                 NaN
# 618                              NaN                                 NaN
# 1972                             NaN                                 NaN
# 2015                             NaN                                 NaN
# 2038    2 m in first person singular       5 No applicative construction
#
#      10B Nasal Vowels in West Africa 25B Zero Marking of A and P Arguments  \
# 676                              NaN                    2 Non-zero marking
# 684                              NaN                                   NaN
# 689                              NaN                    2 Non-zero marking
# 681                              NaN                                   NaN
# 1868                             NaN                                   NaN
# ...                              ...                                   ...
# 1933                             NaN                                   NaN
# 618                              NaN                                   NaN
# 1972                             NaN                                   NaN
# 2015                             NaN                                   NaN
# 2038                             NaN                    2 Non-zero marking
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 676                          1 monoexponential TAM
# 684                                            NaN
# 689                                2 TAM+agreement
# 681                                            NaN
# 1868                                           NaN
# ...                                            ...
# 1933                                           NaN
# 618                                            NaN
# 1972                                           NaN
# 2015                                           NaN
# 2038                         1 monoexponential TAM
#
#      108B Productivity of the Antipassive Construction  \
# 676                                   4 no antipassive
# 684                                                NaN
# 689                                   4 no antipassive
# 681                                                NaN
# 1868                                               NaN
# ...                                                ...
# 1933                                               NaN
# 618                                                NaN
# 1972                                               NaN
# 2015                                               NaN
# 2038                                  4 no antipassive
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 676                                                 NaN
# 684                                                 NaN
# 689                                                 NaN
# 681                                                 NaN
# 1868                                                NaN
# ...                                                 ...
# 1933                                                NaN
# 618                                                 NaN
# 1972                                                NaN
# 2015                                                NaN
# 2038                                                NaN
#
#      58B Number of Possessive Nouns  \
# 676                 1 None reported
# 684                             NaN
# 689                 1 None reported
# 681                             NaN
# 1868                            NaN
# ...                             ...
# 1933                            NaN
# 618                             NaN
# 1972                            NaN
# 2015                            NaN
# 2038                1 None reported
#
#            79B Suppletion in Imperatives and Hortatives
# 676                                        2 Imperative
# 684                                                 NaN
# 689   5 None (= no suppletive imperatives reported i...
# 681                                                 NaN
# 1868                                                NaN
# ...                                                 ...
# 1933                                                NaN
# 618                                                 NaN
# 1972                                                NaN
# 2015                                                NaN
# 2038                                       2 Imperative
#
# [70 rows x 202 columns]

# %%
walsdata_test[110:]
# Out:
#      wals_code iso_code glottocode                       Name   latitude  \
# 2205       swt      ssw   swat1243                      Swati -26.500000
# 2192       sun      sun   sund1252                  Sundanese  -7.000000
# 2201       swa      swh   swah1253                    Swahili  -6.500000
# 2378       tsk      taq   tama1365                   Tamashek  20.000000
# 2248       tel      tel   telu1262                     Telugu  16.000000
# 2215       taj      tgk   taji1245                      Tajik  38.666667
# 2212       tag      tgl   taga1270                    Tagalog  15.000000
# 2268       tha      tha   thai1261                       Thai  16.000000
# 2284       tig      tir   tigr1271                   Tigrinya  14.500000
# 2354       tpi      tpi   tokp1240                  Tok Pisin  -9.500000
# 2386       tsw      tsn   tswa1253                     Tswana -24.000000
# 2381       tsn      tso   tson1249                     Tsonga -24.000000
# 2297       tkm      tuk   turk1304                    Turkmen  40.000000
# 2405       tur      tur   nucl1301                    Turkish  39.000000
# 2461       uyg      uig   uigh1240                     Uyghur  40.000000
# 2435       ukr      ukr   ukra1253                  Ukrainian  49.000000
# 2441       umb      umb   umbu1257                    UMbundu -12.500000
# 2448       urd      urd   urdu1245                       Urdu  25.000000
# 2472       vie      vie   viet1252                 Vietnamese  10.500000
# 2552       wwy      war   wara1300                Waray-Waray  12.000000
# 2511       wlf      wol   nucl1347                      Wolof  15.250000
# 2561       xho      xho   xhos1239                      Xhosa -32.000000
# 2625       yor      yor   yoru1245                     Yoruba   8.000000
# 482        cnt      yue   yuec1235                  Cantonese  23.000000
# 1508       mly      zsm   stan1306                      Malay   3.000000
# 100        ams      arb   stan1318   Arabic (Modern Standard)  25.000000
# 140        arm      hye   nucl1235         Armenian (Eastern)  40.000000
# 193        aze      azb   nort2697                Azerbaijani  40.500000
# 298        bma      tzm   cent2194      Berber (Middle Atlas)  33.000000
# 372        bsq      eus   basq1248                     Basque  43.000000
# 628        dut      nld   dutc1256                      Dutch  52.500000
# 665        ewe      ewe   ewee1241                        Ewe   6.333333
# 675        fij      fij   fiji1243                     Fijian -17.833333
# 732        ger      deu   stan1295                     German  52.000000
# 783        grk      ell   mode1248             Greek (Modern)  39.000000
# 836        heb      heb   hebr1245            Hebrew (Modern)  31.500000
# 918        ind      ind   indo1316                 Indonesian   0.000000
# 930        iri      gle   iris1253                      Irish  53.000000
# 944        ita      ita   ital1282                    Italian  43.000000
# 1059       kgz      kir   kirg1245                    Kirghiz  42.000000
# 1183       krd      kmr   nort2641          Kurdish (Central)  36.000000
# 1547       mol      ron   roma1327                  Moldavian  47.000000
# 2091       shn      sna   shon1251                      Shona -18.000000
# 2155       spa      spa   stan1288                    Spanish  40.000000
# 2202       swe      swe   swed1254                    Swedish  60.000000
# 2280       tib      bod   tibe1272  Tibetan (Standard Spoken)  30.000000
# 2313       tml      tam   tami1289                      Tamil  11.000000
# 2411       tvo      tat   tata1255                      Tatar  56.000000
# 2463       uzn      uzn   nort2690           Uzbek (Northern)  40.666667
# 2498       wel      cym   wels1247                      Welsh  52.000000
# 2588       ydd      ydd   yidd1255                    Yiddish  52.000000
# 2675       zul      zul   zulu1248                       Zulu -30.000000
#
#        longitude                       genus          family  macroarea  \
# 2205   31.000000                     Bantoid     Niger-Congo     Africa
# 2192  107.000000             Malayo-Sumbawan    Austronesian  Papunesia
# 2201   39.000000                     Bantoid     Niger-Congo     Africa
# 2378   -2.000000                      Berber    Afro-Asiatic     Africa
# 2248   79.000000     South-Central Dravidian       Dravidian    Eurasia
# 2215   70.000000                     Iranian   Indo-European    Eurasia
# 2212  121.000000  Greater Central Philippine    Austronesian  Papunesia
# 2268  101.000000                     Kam-Tai       Tai-Kadai    Eurasia
# 2284   38.500000                     Semitic    Afro-Asiatic     Africa
# 2354  147.166667         Creoles and Pidgins           other  Papunesia
# 2386   26.000000                     Bantoid     Niger-Congo     Africa
# 2381   32.000000                     Bantoid     Niger-Congo     Africa
# 2297   58.000000                      Turkic          Altaic    Eurasia
# 2405   35.000000                      Turkic          Altaic    Eurasia
# 2461   80.000000                      Turkic          Altaic    Eurasia
# 2435   33.000000                      Slavic   Indo-European    Eurasia
# 2441   15.000000                     Bantoid     Niger-Congo     Africa
# 2448   67.000000                       Indic   Indo-European    Eurasia
# 2472  106.500000                  Viet-Muong  Austro-Asiatic    Eurasia
# 2552  125.000000  Greater Central Philippine    Austronesian  Papunesia
# 2511  -16.000000           Northern Atlantic     Niger-Congo     Africa
# 2561   27.000000                     Bantoid     Niger-Congo     Africa
# 2625    4.333333                      Defoid     Niger-Congo     Africa
# 482   113.000000                     Chinese    Sino-Tibetan    Eurasia
# 1508  102.000000             Malayo-Sumbawan    Austronesian    Eurasia
# 100    42.000000                     Semitic    Afro-Asiatic    Eurasia
# 140    45.000000                    Armenian   Indo-European    Eurasia
# 193    48.500000                      Turkic          Altaic    Eurasia
# 298    -5.000000                      Berber    Afro-Asiatic     Africa
# 372    -3.000000                      Basque          Basque    Eurasia
# 628     6.000000                    Germanic   Indo-European    Eurasia
# 665     0.416667                         Kwa     Niger-Congo     Africa
# 675   178.000000                     Oceanic    Austronesian  Papunesia
# 732    10.000000                    Germanic   Indo-European    Eurasia
# 783    22.000000                       Greek   Indo-European    Eurasia
# 836    34.833333                     Semitic    Afro-Asiatic    Eurasia
# 918   106.000000             Malayo-Sumbawan    Austronesian  Papunesia
# 930    -8.000000                      Celtic   Indo-European    Eurasia
# 944    12.000000                     Romance   Indo-European    Eurasia
# 1059   75.000000                      Turkic          Altaic    Eurasia
# 1183   44.000000                     Iranian   Indo-European    Eurasia
# 1547   29.000000                     Romance   Indo-European    Eurasia
# 2091   31.000000                     Bantoid     Niger-Congo     Africa
# 2155   -4.000000                     Romance   Indo-European    Eurasia
# 2202   15.000000                    Germanic   Indo-European    Eurasia
# 2280   91.000000                       Bodic    Sino-Tibetan    Eurasia
# 2313   78.500000          Southern Dravidian       Dravidian    Eurasia
# 2411   49.500000                      Turkic          Altaic    Eurasia
# 2463   66.500000                      Turkic          Altaic    Eurasia
# 2498   -3.000000                      Celtic   Indo-European    Eurasia
# 2588   23.000000                    Germanic   Indo-European    Eurasia
# 2675   30.000000                     Bantoid     Niger-Congo     Africa
#
#                                            countrycodes  ...  \
# 2205                                              ZA SZ  ...
# 2192                                                 ID  ...
# 2201                                                 TZ  ...
# 2378                                                 ML  ...
# 2248                                                 IN  ...
# 2215                                                 TJ  ...
# 2212                                                 PH  ...
# 2268                                                 TH  ...
# 2284                                              ER ET  ...
# 2354                                                 PG  ...
# 2386                                              BW ZA  ...
# 2381                                              MZ ZA  ...
# 2297                                                 TM  ...
# 2405                                                 TR  ...
# 2461                                                 CN  ...
# 2435                                                 UA  ...
# 2441                                                 AO  ...
# 2448                                                 PK  ...
# 2472                                                 VN  ...
# 2552                                                 PH  ...
# 2511                                              SN GM  ...
# 2561                                                 ZA  ...
# 2625                                              NG BJ  ...
# 482                                                  CN  ...
# 1508                                                 MY  ...
# 100   KM KW SO SY OM QA EG TN MA LY JO LB ER YE SA I...  ...
# 140                                                  AM  ...
# 193                                               AZ IR  ...
# 298                                                  MA  ...
# 372                                               FR ES  ...
# 628                                                  NL  ...
# 665                                               TG GH  ...
# 675                                                  FJ  ...
# 732                                            AT DE CH  ...
# 783                                                  GR  ...
# 836                                                  IL  ...
# 918                                                  ID  ...
# 930                                                  IE  ...
# 944                                               IT CH  ...
# 1059                                                 KG  ...
# 1183                                              IQ IR  ...
# 1547                                                 MD  ...
# 2091                                                 ZW  ...
# 2155                                                 ES  ...
# 2202                                              FI SE  ...
# 2280                                                 CN  ...
# 2313                                              LK IN  ...
# 2411                                                 RU  ...
# 2463                                                 UZ  ...
# 2498                                                 GB  ...
# 2588                                     LT PL DE BY UA  ...
# 2675                                                 ZA  ...
#
#       137B M in Second Person Singular  136B M in First Person Singular  \
# 2205                               NaN                              NaN
# 2192                               NaN                              NaN
# 2201  1 No m in second person singular     2 m in first person singular
# 2378                               NaN                              NaN
# 2248                               NaN                              NaN
# 2215                               NaN                              NaN
# 2212     2 m in second person singular  1 No m in first person singular
# 2268                               NaN                              NaN
# 2284                               NaN                              NaN
# 2354                               NaN                              NaN
# 2386                               NaN                              NaN
# 2381                               NaN                              NaN
# 2297                               NaN                              NaN
# 2405  1 No m in second person singular     2 m in first person singular
# 2461                               NaN                              NaN
# 2435                               NaN                              NaN
# 2441                               NaN                              NaN
# 2448                               NaN                              NaN
# 2472     2 m in second person singular  1 No m in first person singular
# 2552                               NaN                              NaN
# 2511                               NaN                              NaN
# 2561                               NaN                              NaN
# 2625  1 No m in second person singular     2 m in first person singular
# 482                                NaN                              NaN
# 1508                               NaN                              NaN
# 100                                NaN                              NaN
# 140                                NaN                              NaN
# 193                                NaN                              NaN
# 298      2 m in second person singular  1 No m in first person singular
# 372   1 No m in second person singular  1 No m in first person singular
# 628                                NaN                              NaN
# 665                                NaN                              NaN
# 675      2 m in second person singular  1 No m in first person singular
# 732   1 No m in second person singular     2 m in first person singular
# 783   1 No m in second person singular     2 m in first person singular
# 836   1 No m in second person singular  1 No m in first person singular
# 918      2 m in second person singular  1 No m in first person singular
# 930                                NaN                              NaN
# 944                                NaN                              NaN
# 1059                               NaN                              NaN
# 1183                               NaN                              NaN
# 1547                               NaN                              NaN
# 2091                               NaN                              NaN
# 2155  1 No m in second person singular     2 m in first person singular
# 2202                               NaN                              NaN
# 2280  1 No m in second person singular  1 No m in first person singular
# 2313                               NaN                              NaN
# 2411                               NaN                              NaN
# 2463                               NaN                              NaN
# 2498                               NaN                              NaN
# 2588                               NaN                              NaN
# 2675  1 No m in second person singular     2 m in first person singular
#
#         109B Other Roles of Applied Objects 10B Nasal Vowels in West Africa  \
# 2205                                    NaN                             NaN
# 2192                                    NaN                             NaN
# 2201                             2 Locative                             NaN
# 2378                                    NaN                             NaN
# 2248                                    NaN                             NaN
# 2215                                    NaN                             NaN
# 2212              3 Instrument and locative                             NaN
# 2268          5 No applicative construction                             NaN
# 2284                                    NaN                             NaN
# 2354                                    NaN                             NaN
# 2386                                    NaN                             NaN
# 2381                                    NaN                             NaN
# 2297                                    NaN                             NaN
# 2405          5 No applicative construction                             NaN
# 2461                                    NaN                             NaN
# 2435          5 No applicative construction                             NaN
# 2441                                    NaN                             NaN
# 2448                                    NaN                             NaN
# 2472          5 No applicative construction                             NaN
# 2552                                    NaN                             NaN
# 2511              3 Instrument and locative                             NaN
# 2561                                    NaN                             NaN
# 2625          5 No applicative construction                             NaN
# 482                                     NaN                             NaN
# 1508                                    NaN                             NaN
# 100                                     NaN                             NaN
# 140           5 No applicative construction                             NaN
# 193                                     NaN                             NaN
# 298           5 No applicative construction                             NaN
# 372           5 No applicative construction                             NaN
# 628                                     NaN                             NaN
# 665           5 No applicative construction                             NaN
# 675                              2 Locative                             NaN
# 732           5 No applicative construction                             NaN
# 783           5 No applicative construction                             NaN
# 836           5 No applicative construction                             NaN
# 918   4 No other roles (= Only benefactive)                             NaN
# 930                                     NaN                             NaN
# 944                                     NaN                             NaN
# 1059          5 No applicative construction                             NaN
# 1183                                    NaN                             NaN
# 1547                                    NaN                             NaN
# 2091                                    NaN                             NaN
# 2155          5 No applicative construction                             NaN
# 2202                                    NaN                             NaN
# 2280                                    NaN                             NaN
# 2313          5 No applicative construction                             NaN
# 2411                                    NaN                             NaN
# 2463                                    NaN                             NaN
# 2498                                    NaN                             NaN
# 2588                                    NaN                             NaN
# 2675                           1 Instrument                             NaN
#
#      25B Zero Marking of A and P Arguments  \
# 2205                                   NaN
# 2192                                   NaN
# 2201                    2 Non-zero marking
# 2378                                   NaN
# 2248                                   NaN
# 2215                                   NaN
# 2212                    2 Non-zero marking
# 2268                        1 Zero-marking
# 2284                                   NaN
# 2354                                   NaN
# 2386                                   NaN
# 2381                                   NaN
# 2297                                   NaN
# 2405                    2 Non-zero marking
# 2461                                   NaN
# 2435                                   NaN
# 2441                                   NaN
# 2448                                   NaN
# 2472                        1 Zero-marking
# 2552                                   NaN
# 2511                                   NaN
# 2561                                   NaN
# 2625                    2 Non-zero marking
# 482                                    NaN
# 1508                                   NaN
# 100                                    NaN
# 140                                    NaN
# 193                                    NaN
# 298                     2 Non-zero marking
# 372                     2 Non-zero marking
# 628                                    NaN
# 665                         1 Zero-marking
# 675                     2 Non-zero marking
# 732                     2 Non-zero marking
# 783                     2 Non-zero marking
# 836                     2 Non-zero marking
# 918                         1 Zero-marking
# 930                                    NaN
# 944                                    NaN
# 1059                                   NaN
# 1183                                   NaN
# 1547                                   NaN
# 2091                                   NaN
# 2155                    2 Non-zero marking
# 2202                                   NaN
# 2280                    2 Non-zero marking
# 2313                                   NaN
# 2411                                   NaN
# 2463                                   NaN
# 2498                                   NaN
# 2588                                   NaN
# 2675                    2 Non-zero marking
#
#      21B Exponence of Tense-Aspect-Mood Inflection  \
# 2205                                           NaN
# 2192                                           NaN
# 2201                         1 monoexponential TAM
# 2378                                           NaN
# 2248                                           NaN
# 2215                                           NaN
# 2212                         1 monoexponential TAM
# 2268                         1 monoexponential TAM
# 2284                                           NaN
# 2354                                           NaN
# 2386                                           NaN
# 2381                                           NaN
# 2297                                           NaN
# 2405                         1 monoexponential TAM
# 2461                                           NaN
# 2435                                           NaN
# 2441                                           NaN
# 2448                                           NaN
# 2472                         1 monoexponential TAM
# 2552                                           NaN
# 2511                                           NaN
# 2561                                           NaN
# 2625                         1 monoexponential TAM
# 482                                            NaN
# 1508                                           NaN
# 100                                            NaN
# 140                                            NaN
# 193                                            NaN
# 298                          1 monoexponential TAM
# 372                          1 monoexponential TAM
# 628                                            NaN
# 665                                            NaN
# 675                          1 monoexponential TAM
# 732                          1 monoexponential TAM
# 783                      3 TAM+agreement+diathesis
# 836                      3 TAM+agreement+diathesis
# 918                          1 monoexponential TAM
# 930                                            NaN
# 944                                            NaN
# 1059                                           NaN
# 1183                                           NaN
# 1547                                           NaN
# 2091                                           NaN
# 2155                               2 TAM+agreement
# 2202                                           NaN
# 2280                               2 TAM+agreement
# 2313                                           NaN
# 2411                                           NaN
# 2463                                           NaN
# 2498                                           NaN
# 2588                                           NaN
# 2675                         1 monoexponential TAM
#
#      108B Productivity of the Antipassive Construction  \
# 2205                                               NaN
# 2192                                               NaN
# 2201                                  4 no antipassive
# 2378                                               NaN
# 2248                                               NaN
# 2215                                               NaN
# 2212                                  4 no antipassive
# 2268                                  4 no antipassive
# 2284                                               NaN
# 2354                                               NaN
# 2386                                               NaN
# 2381                                               NaN
# 2297                                               NaN
# 2405                                  4 no antipassive
# 2461                                               NaN
# 2435                                  4 no antipassive
# 2441                                               NaN
# 2448                                               NaN
# 2472                                  4 no antipassive
# 2552                                               NaN
# 2511                                               NaN
# 2561                                               NaN
# 2625                                  4 no antipassive
# 482                                                NaN
# 1508                                               NaN
# 100                                                NaN
# 140                                   4 no antipassive
# 193                                                NaN
# 298                                   4 no antipassive
# 372                             2 partially productive
# 628                                                NaN
# 665                                   4 no antipassive
# 675                                   4 no antipassive
# 732                                   4 no antipassive
# 783                                   4 no antipassive
# 836                                   4 no antipassive
# 918                                   4 no antipassive
# 930                                                NaN
# 944                                                NaN
# 1059                                  4 no antipassive
# 1183                                               NaN
# 1547                                               NaN
# 2091                                               NaN
# 2155                                  4 no antipassive
# 2202                                               NaN
# 2280                                               NaN
# 2313                                  4 no antipassive
# 2411                                               NaN
# 2463                                               NaN
# 2498                                               NaN
# 2588                                               NaN
# 2675                                  4 no antipassive
#
#      130B Cultural Categories of Languages with Identity of 'Finger' and 'Hand'  \
# 2205                                                NaN
# 2192                                                NaN
# 2201                                                NaN
# 2378                                                NaN
# 2248                                                NaN
# 2215                                                NaN
# 2212                                                NaN
# 2268                                                NaN
# 2284                                                NaN
# 2354                                                NaN
# 2386                                                NaN
# 2381                                                NaN
# 2297                                                NaN
# 2405                                                NaN
# 2461                                                NaN
# 2435                                                NaN
# 2441                                                NaN
# 2448                                                NaN
# 2472                                                NaN
# 2552                                                NaN
# 2511                                                NaN
# 2561                                                NaN
# 2625                                                NaN
# 482                                                 NaN
# 1508                                                NaN
# 100                                                 NaN
# 140                                                 NaN
# 193                                                 NaN
# 298                                                 NaN
# 372                                                 NaN
# 628                                                 NaN
# 665                                                 NaN
# 675                                                 NaN
# 732                                                 NaN
# 783                                                 NaN
# 836                                                 NaN
# 918                                                 NaN
# 930                                                 NaN
# 944                                                 NaN
# 1059                                                NaN
# 1183                                                NaN
# 1547                                                NaN
# 2091                                                NaN
# 2155                                                NaN
# 2202                                                NaN
# 2280                                                NaN
# 2313                                                NaN
# 2411                                                NaN
# 2463                                                NaN
# 2498                                                NaN
# 2588                                                NaN
# 2675                                                NaN
#
#      58B Number of Possessive Nouns  \
# 2205                            NaN
# 2192                            NaN
# 2201                1 None reported
# 2378                            NaN
# 2248                            NaN
# 2215                            NaN
# 2212                1 None reported
# 2268                1 None reported
# 2284                            NaN
# 2354                            NaN
# 2386                            NaN
# 2381                            NaN
# 2297                            NaN
# 2405                1 None reported
# 2461                            NaN
# 2435                            NaN
# 2441                            NaN
# 2448                            NaN
# 2472                1 None reported
# 2552                            NaN
# 2511                            NaN
# 2561                            NaN
# 2625                1 None reported
# 482                             NaN
# 1508                            NaN
# 100                             NaN
# 140                 1 None reported
# 193                             NaN
# 298                 1 None reported
# 372                 1 None reported
# 628                             NaN
# 665                 1 None reported
# 675                   3 Two to four
# 732                 1 None reported
# 783                 1 None reported
# 836                 1 None reported
# 918                 1 None reported
# 930                             NaN
# 944                             NaN
# 1059                            NaN
# 1183                            NaN
# 1547                            NaN
# 2091                            NaN
# 2155                1 None reported
# 2202                            NaN
# 2280                1 None reported
# 2313                            NaN
# 2411                            NaN
# 2463                            NaN
# 2498                            NaN
# 2588                            NaN
# 2675                1 None reported
#
#            79B Suppletion in Imperatives and Hortatives
# 2205                                                NaN
# 2192                                                NaN
# 2201                                       2 Imperative
# 2378                                                NaN
# 2248                                                NaN
# 2215                                                NaN
# 2212  5 None (= no suppletive imperatives reported i...
# 2268  5 None (= no suppletive imperatives reported i...
# 2284                                                NaN
# 2354                                                NaN
# 2386                                                NaN
# 2381                                                NaN
# 2297                                                NaN
# 2405  5 None (= no suppletive imperatives reported i...
# 2461                                                NaN
# 2435  5 None (= no suppletive imperatives reported i...
# 2441                                                NaN
# 2448                                                NaN
# 2472  5 None (= no suppletive imperatives reported i...
# 2552                                                NaN
# 2511                                                NaN
# 2561                                                NaN
# 2625  5 None (= no suppletive imperatives reported i...
# 482   5 None (= no suppletive imperatives reported i...
# 1508                                                NaN
# 100                                                 NaN
# 140                                        2 Imperative
# 193                                                 NaN
# 298         1 A regular and a suppletive form alternate
# 372   5 None (= no suppletive imperatives reported i...
# 628   5 None (= no suppletive imperatives reported i...
# 665   5 None (= no suppletive imperatives reported i...
# 675   5 None (= no suppletive imperatives reported i...
# 732   5 None (= no suppletive imperatives reported i...
# 783                                        2 Imperative
# 836   5 None (= no suppletive imperatives reported i...
# 918   5 None (= no suppletive imperatives reported i...
# 930                                        2 Imperative
# 944                                                 NaN
# 1059                                                NaN
# 1183                                                NaN
# 1547                                                NaN
# 2091                                                NaN
# 2155                                       2 Imperative
# 2202  5 None (= no suppletive imperatives reported i...
# 2280                                                NaN
# 2313                                                NaN
# 2411                                                NaN
# 2463                                                NaN
# 2498                                                NaN
# 2588                                                NaN
# 2675  5 None (= no suppletive imperatives reported i...
#
# [52 rows x 202 columns]

# %% [markdown]
# #### Extract scriptdata from NLLB and merge with WALS

# %%
# extract script data for each language
nllb_lang['Script'] = nllb_lang['FLORES-200 code'].str[-4:]

# change merge column name
nllb_lang.rename(columns = {'Language':'Name'}, inplace = True) 

# Change names that differ in the nllb language name and wals language name
nllb_lang.loc[nllb_lang['Name'] == 'Norwegian Nynorsk', 'Name'] = 'Norwegian'
nllb_lang.loc[nllb_lang['Name'] == 'Serbian', 'Name'] = 'Serbian-Croatian'
nllb_lang.loc[nllb_lang['Name'] == 'Slovenian', 'Name'] = 'Slovene'
nllb_lang.loc[nllb_lang['Name'] == 'Chinese (Traditional)', 'Name'] = 'Mandarin'

# merge the script values to the WALS dataset based on the language name
walsdata_test = pd.merge(walsdata_test, nllb_lang)

# rename walsdata language names for simplicity
walsdata_test.loc[walsdata_test['Name'] == 'Mandarin', 'Name'] = 'Chinese'

walsdata_test.shape
# Out:
# (30, 204)

# %% [markdown]
# #### Remove languages with <25 features filled and remove features with <10% coverage

# %%
mask = walsdata_test.isnull().sum(axis=1) >= 25

removed1 = len(walsdata_test) - len(mask)

walsdata_test = walsdata_test[mask]

print('Removed languages (<25 features):',removed1)
# Out:
# Removed languages (<25 features): 0

# %%
missing_values = walsdata_test.isnull().sum(axis=0)

threshold = len(walsdata_test) - np.ceil(len(walsdata_test)/10)

features_above_threshold = missing_values[missing_values > threshold].index.tolist()

walsdata_test = walsdata_test.drop(columns=features_above_threshold)

removed2 = len(features_above_threshold)

print('Removed features (<10% coverage):',removed2)
# Out:
# Removed features (<10% coverage): 25

# %%
walsdata_test.head()
# Out:
#   wals_code iso_code glottocode       Name  latitude  longitude     genus  \
# 0       ben      ben   beng1280    Bengali     24.00       90.0     Indic
# 1       bul      bul   bulg1262  Bulgarian     42.50       25.0    Slavic
# 2       ctl      cat   stan1289    Catalan     41.75        2.0   Romance
# 3       cze      ces   czec1258      Czech     50.00       15.0    Slavic
# 4       dsh      dan   dani1285     Danish     56.00       10.0  Germanic
#
#           family macroarea countrycodes  ... 137B M in Second Person Singular  \
# 0  Indo-European   Eurasia        IN BD  ...                              NaN
# 1  Indo-European   Eurasia           BG  ...                              NaN
# 2  Indo-European   Eurasia           ES  ...                              NaN
# 3  Indo-European   Eurasia           CZ  ...                              NaN
# 4  Indo-European   Eurasia           DK  ...                              NaN
#
#   136B M in First Person Singular 109B Other Roles of Applied Objects  \
# 0                             NaN                                 NaN
# 1                             NaN                                 NaN
# 2                             NaN                                 NaN
# 3                             NaN                                 NaN
# 4                             NaN                                 NaN
#
#   25B Zero Marking of A and P Arguments  \
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4                                   NaN
#
#   21B Exponence of Tense-Aspect-Mood Inflection  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#   108B Productivity of the Antipassive Construction  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   58B Number of Possessive Nouns  \
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
#         79B Suppletion in Imperatives and Hortatives FLORES-200 code Script
# 0  5 None (= no suppletive imperatives reported i...        ben_Beng   Beng
# 1        1 A regular and a suppletive form alternate        bul_Cyrl   Cyrl
# 2                                                NaN        cat_Latn   Latn
# 3  5 None (= no suppletive imperatives reported i...        ces_Latn   Latn
# 4                                                NaN        dan_Latn   Latn
#
# [5 rows x 179 columns]

# %% [markdown]
# #### Select relevant features

# %%
### feature groups
# genus = ['genus']
# family = ['family']
# script = ['Script']
# phonology = ['1A Consonant Inventories','2A Vowel Quality Inventories','3A Consonant-Vowel Ratio','4A Voicing in Plosives and Fricatives','5A Voicing and Gaps in Plosive Systems','6A Uvular Consonants','7A Glottalized Consonants','8A Lateral Consonants','9A The Velar Nasal','10A Vowel Nasalization','11A Front Rounded Vowels','12A Syllable Structure','13A Tone','14A Fixed Stress Locations','15A Weight-Sensitive Stress','16A Weight Factors in Weight-Sensitive Stress Systems','17A Rhythm Types','18A Absence of Common Consonants','19A Presence of Uncommon Consonants']
# morphology = ['20A Fusion of Selected Inflectional Formatives','21A Exponence of Selected Inflectional Formatives','22A Inflectional Synthesis of the Verb','23A Locus of Marking in the Clause','24A Locus of Marking in Possessive Noun Phrases','25A Locus of Marking: Whole-language Typology','26A Prefixing vs. Suffixing in Inflectional Morphology','27A Reduplication','28A Case Syncretism','29A Syncretism in Verbal Person/Number Marking']
# nominal_cat = ['30A Number of Genders','31A Sex-based and Non-sex-based Gender Systems','32A Systems of Gender Assignment','33A Coding of Nominal Plurality','34A Occurrence of Nominal Plurality','35A Plurality in Independent Personal Pronouns','36A The Associative Plural','37A Definite Articles','38A Indefinite Articles','39A Inclusive/Exclusive Distinction in Independent Pronouns','40A Inclusive/Exclusive Distinction in Verbal Inflection','41A Distance Contrasts in Demonstratives','42A Pronominal and Adnominal Demonstratives','43A Third Person Pronouns and Demonstratives','44A Gender Distinctions in Independent Personal Pronouns','45A Politeness Distinctions in Pronouns','46A Indefinite Pronouns','47A Intensifiers and Reflexive Pronouns','48A Person Marking on Adpositions','49A Number of Cases','50A Asymmetrical Case-Marking','51A Position of Case Affixes','52A Comitatives and Instrumentals','53A Ordinal Numerals','54A Distributive Numerals','55A Numeral Classifiers','56A Conjunctions and Universal Quantifiers','57A Position of Pronominal Possessive Affixes']
# nominal_syn = ['58A Obligatory Possessive Inflection','59A Possessive Classification','60A Genitives, Adjectives and Relative Clauses','61A Adjectives without Nouns','62A Action Nominal Constructions','63A Noun Phrase Conjunction','64A Nominal and Verbal Conjunction']
# verbal_cat = ['65A Perfective/Imperfective Aspect','66A The Past Tense','67A The Future Tense','68A The Perfect','69A Position of Tense-Aspect Affixes','70A The Morphological Imperative','71A The Prohibitive','72A Imperative-Hortative Systems','73A The Optative','74A Situational Possibility','75A Epistemic Possibility','76A Overlap between Situational and Epistemic Modal Marking','77A Semantic Distinctions of Evidentiality','78A Coding of Evidentiality','79A Suppletion According to Tense and Aspect','80A Verbal Number and Suppletion']
# wordorder = ['81A Order of Subject, Object and Verb','82A Order of Subject and Verb','83A Order of Object and Verb','84A Order of Object, Oblique, and Verb','85A Order of Adposition and Noun Phrase','86A Order of Genitive and Noun','87A Order of Adjective and Noun','88A Order of Demonstrative and Noun','89A Order of Numeral and Noun','90A Order of Relative Clause and Noun','91A Order of Degree Word and Adjective','92A Position of Polar Question Particles','93A Position of Interrogative Phrases in Content Questions','94A Order of Adverbial Subordinator and Clause','95A Relationship between the Order of Object and Verb and the Order of Adposition and Noun Phrase','96A Relationship between the Order of Object and Verb and the Order of Relative Clause and Noun','97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun','143A Order of Negative Morpheme and Verb','143B Obligatory Double Negation','143C Optional Double Negation','143D Optional Triple Negation','143E Preverbal Negative Morphemes','143F Postverbal Negative Morphemes','143G Minor morphological means of signaling negation','144A Position of Negative Word With Respect to Subject, Object, and Verb','144B Position of negative words relative to beginning and end of clause and with respect to adjacency to verb','144C Languages with different word order in negative clauses','144D The Position of Negative Morphemes in SVO Languages','144E Multiple Negative Constructions in SVO Languages','144F Obligatory Double Negation in SVO languages','144G Optional Double Negation in SVO languages','144H NegSVO Order','144I SNegVO Order','144J SVNegO Order','144K SVONeg Order','144L The Position of Negative Morphemes in SOV Languages','144M Multiple Negative Constructions in SOV Languages','144N Obligatory Double Negation in SOV languages','144O Optional Double Negation in SOV languages','144P NegSOV Order','144Q SNegOV Order','144R SONegV Order','144S SOVNeg Order','144T The Position of Negative Morphemes in Verb-Initial Languages','144U Double negation in verb-initial languages','144V Verb-Initial with Preverbal Negative','144W Verb-Initial with Negative that is Immediately Postverbal or between Subject and Object','144X Verb-Initial with Clause-Final Negative','144Y The Position of Negative Morphemes in Object-Initial Languages']
# simple_clause = ["100A Alignment of Verbal Person Marking","101A Expression of Pronominal Subjects","102A Verbal Person Marking","103A Third Person Zero of Verbal Person Marking","104A Order of Person Markers on the Verb","105A Ditransitive Constructions: The Verb 'Give'","106A Reciprocal Constructions","107A Passive Constructions","108A Antipassive Constructions","108B Productivity of the Antipassive Construction","109A Applicative Constructions","109B Other Roles of Applied Objects","110A Periphrastic Causative Constructions","111A Nonperiphrastic Causative Constructions","112A Negative Morphemes","113A Symmetric and Asymmetric Standard Negation","114A Subtypes of Asymmetric Standard Negation","115A Negative Indefinite Pronouns and Predicate Negation","116A Polar Questions","117A Predicative Possession","118A Predicative Adjectives","119A Nominal and Locational Predication","120A Zero Copula for Predicate Nominals","121A Comparative Constructions"]
# complex_sentences = ["122A Relativization on Subjects","123A Relativization on Obliques","124A 'Want' Complement Subjects","125A Purpose Clauses","126A 'When' Clauses","127A Reason Clauses","128A Utterance Complement Clauses"]
# lexicon = ['129A Hand and Arm','130A Finger and Hand','131A Numeral Bases','132A Number of Non-Derived Basic Colour Categories','133A Number of Basic Colour Categories','134A Green and Blue','135A Red and Yellow','136A M-T Pronouns','137A N-M Pronouns','138A Tea']

genus = ['genus']
family = ['family']
script = ['Script']
geo = ['longitude','latitude']
phonology = ['1A Consonant Inventories','2A Vowel Quality Inventories','3A Consonant-Vowel Ratio','4A Voicing in Plosives and Fricatives','5A Voicing and Gaps in Plosive Systems','6A Uvular Consonants','7A Glottalized Consonants','8A Lateral Consonants','9A The Velar Nasal','10A Vowel Nasalization','11A Front Rounded Vowels','12A Syllable Structure','13A Tone','14A Fixed Stress Locations','15A Weight-Sensitive Stress','16A Weight Factors in Weight-Sensitive Stress Systems','17A Rhythm Types','18A Absence of Common Consonants','19A Presence of Uncommon Consonants']
morphology = ['20A Fusion of Selected Inflectional Formatives','21A Exponence of Selected Inflectional Formatives','22A Inflectional Synthesis of the Verb','23A Locus of Marking in the Clause','24A Locus of Marking in Possessive Noun Phrases','25A Locus of Marking: Whole-language Typology','26A Prefixing vs. Suffixing in Inflectional Morphology','27A Reduplication','28A Case Syncretism','29A Syncretism in Verbal Person/Number Marking']
nominal_cat = ['30A Number of Genders','31A Sex-based and Non-sex-based Gender Systems','32A Systems of Gender Assignment','33A Coding of Nominal Plurality','34A Occurrence of Nominal Plurality','35A Plurality in Independent Personal Pronouns','36A The Associative Plural','37A Definite Articles','38A Indefinite Articles','39A Inclusive/Exclusive Distinction in Independent Pronouns','40A Inclusive/Exclusive Distinction in Verbal Inflection','41A Distance Contrasts in Demonstratives','42A Pronominal and Adnominal Demonstratives','43A Third Person Pronouns and Demonstratives','44A Gender Distinctions in Independent Personal Pronouns','45A Politeness Distinctions in Pronouns','46A Indefinite Pronouns','47A Intensifiers and Reflexive Pronouns','48A Person Marking on Adpositions','49A Number of Cases','50A Asymmetrical Case-Marking','51A Position of Case Affixes','52A Comitatives and Instrumentals','53A Ordinal Numerals','54A Distributive Numerals','55A Numeral Classifiers','56A Conjunctions and Universal Quantifiers','57A Position of Pronominal Possessive Affixes']
nominal_syn = ['58A Obligatory Possessive Inflection','59A Possessive Classification','60A Genitives, Adjectives and Relative Clauses','61A Adjectives without Nouns','62A Action Nominal Constructions','63A Noun Phrase Conjunction','64A Nominal and Verbal Conjunction']
verbal_cat = ['65A Perfective/Imperfective Aspect','66A The Past Tense','67A The Future Tense','68A The Perfect','69A Position of Tense-Aspect Affixes','70A The Morphological Imperative','71A The Prohibitive','72A Imperative-Hortative Systems','73A The Optative','74A Situational Possibility','75A Epistemic Possibility','76A Overlap between Situational and Epistemic Modal Marking','77A Semantic Distinctions of Evidentiality','78A Coding of Evidentiality','79A Suppletion According to Tense and Aspect','80A Verbal Number and Suppletion']
wordorder = ['81A Order of Subject, Object and Verb','82A Order of Subject and Verb','83A Order of Object and Verb','84A Order of Object, Oblique, and Verb','85A Order of Adposition and Noun Phrase','86A Order of Genitive and Noun','87A Order of Adjective and Noun','88A Order of Demonstrative and Noun','89A Order of Numeral and Noun','90A Order of Relative Clause and Noun','91A Order of Degree Word and Adjective','92A Position of Polar Question Particles','93A Position of Interrogative Phrases in Content Questions','94A Order of Adverbial Subordinator and Clause','95A Relationship between the Order of Object and Verb and the Order of Adposition and Noun Phrase','96A Relationship between the Order of Object and Verb and the Order of Relative Clause and Noun','97A Relationship between the Order of Object and Verb and the Order of Adjective and Noun','143A Order of Negative Morpheme and Verb','143E Preverbal Negative Morphemes','143F Postverbal Negative Morphemes','143G Minor morphological means of signaling negation','144A Position of Negative Word With Respect to Subject, Object, and Verb','144B Position of negative words relative to beginning and end of clause and with respect to adjacency to verb','144D The Position of Negative Morphemes in SVO Languages','144E Multiple Negative Constructions in SVO Languages','144H NegSVO Order','144I SNegVO Order','144J SVNegO Order','144K SVONeg Order','144L The Position of Negative Morphemes in SOV Languages','144Q SNegOV Order','144R SONegV Order','144S SOVNeg Order']
simple_clause = ["100A Alignment of Verbal Person Marking","101A Expression of Pronominal Subjects","102A Verbal Person Marking","103A Third Person Zero of Verbal Person Marking","104A Order of Person Markers on the Verb","105A Ditransitive Constructions: The Verb 'Give'","106A Reciprocal Constructions","107A Passive Constructions","108A Antipassive Constructions","108B Productivity of the Antipassive Construction","109A Applicative Constructions","109B Other Roles of Applied Objects","110A Periphrastic Causative Constructions","111A Nonperiphrastic Causative Constructions","112A Negative Morphemes","113A Symmetric and Asymmetric Standard Negation","114A Subtypes of Asymmetric Standard Negation","115A Negative Indefinite Pronouns and Predicate Negation","116A Polar Questions","117A Predicative Possession","118A Predicative Adjectives","119A Nominal and Locational Predication","120A Zero Copula for Predicate Nominals","121A Comparative Constructions"]
complex_sentences = ["122A Relativization on Subjects","123A Relativization on Obliques","124A 'Want' Complement Subjects","125A Purpose Clauses","126A 'When' Clauses","127A Reason Clauses","128A Utterance Complement Clauses"]
lexicon = ['129A Hand and Arm','130A Finger and Hand','131A Numeral Bases','132A Number of Non-Derived Basic Colour Categories','133A Number of Basic Colour Categories','134A Green and Blue','135A Red and Yellow','136A M-T Pronouns','137A N-M Pronouns','138A Tea']
other = ['142A Para-Linguistic Usages of Clicks']

# %% [markdown]
# A similarity measure that is designed to handle empty cells is used. Given two languages $A$ and $B$, the $\textrm{shared overlap}(A, B)$ is defined to as
#
# \begin{equation*}
#     \textrm{Shared overlap}(A, B) = \frac{\textrm{\# Features with same values}}{\textrm{\# Features both filled out in WALS}}.
# \end{equation*} \\
#
# This measure can handle language pairs with many empty cells in WALS as it uses only features with cells filled out for both languages, and calculates the percentage of features with the same values.

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(get_sim_df(walsdata_test,walsdata_test['wals_code'],phonology), annot=False, cmap='RdYlGn', fmt=".2f")
plt.title('Language similarity heatmap for phonology features')
plt.show()

# %%
test = get_sim_df(walsdata_test,walsdata_test['wals_code'],genus+family + script + phonology + morphology + nominal_cat + nominal_syn + verbal_cat + wordorder + simple_clause + complex_sentences + lexicon + other)

# %%
# print(test['ben'].sort_values(ascending=False).head(5))
# print(test['ben'].sort_values(ascending=False).tail(5))
# print(test['tel'].sort_values(ascending=False).head(5))
# print(test['tel'].sort_values(ascending=False).tail(5))
# print(test['swa'].sort_values(ascending=False).head(5))
# print(test['swa'].sort_values(ascending=False).tail(5))
print(test['ind'].sort_values(ascending=False).head(5))
print(test['ind'].sort_values(ascending=False).tail(5))
# Out:
# wals_code
# ind    1.00
# vie    0.70
# tha    0.66
# mnd    0.58
# pol    0.57
# Name: ind, dtype: float64
# wals_code
# ger    0.41
# swe    0.40
# dut    0.39
# ben    0.39
# scr    0.38
# Name: ind, dtype: float64

# %%
def lang_sim(lang):
    
    df = pd.DataFrame()

    features = [genus+family,script,phonology,morphology,nominal_cat,nominal_syn,verbal_cat,wordorder,simple_clause,complex_sentences,lexicon,other,genus+family+script+phonology+morphology+nominal_cat+nominal_syn+verbal_cat+wordorder+simple_clause+complex_sentences+lexicon+other]

    for feature in features:
        # print(feature)
        # print(get_sim_df(walsdata_test,walsdata_test['wals_code'],feature)[lang])
        df = pd.concat([df,get_sim_df(walsdata_test,walsdata_test['wals_code'],feature)[lang]],axis=1)
    
    df.columns = ['genus+family','script','phonology','morphology','nominal_cat','nominal_syn','verbal_cat','wordorder','simple_clause','complex_sentences','lexicon','other','All features']
    
    return df

lang_sim('tel')
# Out:
#      genus+family  script  phonology  morphology  nominal_cat  nominal_syn  \
# ben           0.0     0.0       0.77         0.0         1.00          0.0
# bul           0.0     0.0       0.69         1.0         0.33          0.0
# ctl           0.0     0.0       0.69         0.0         0.00          0.0
# cze           0.0     0.0       0.00         0.0         1.00          0.0
# dsh           0.0     0.0       0.00         1.0         0.75          0.0
# dut           0.0     0.0       0.00         1.0         0.50          0.0
# eng           0.0     0.0       0.54         1.0         0.50          0.0
# fin           0.0     0.0       0.62         1.0         1.00          0.0
# fre           0.0     0.0       0.46         1.0         0.17          0.0
# ger           0.0     0.0       0.46         1.0         0.60          0.0
# hun           0.0     0.0       0.62         1.0         0.67          0.0
# ind           0.0     0.0       0.69         1.0         0.50          0.0
# ita           0.0     0.0       0.00         1.0         0.25          0.0
# jpn           0.0     0.0       0.54         1.0         0.67          0.0
# kor           0.0     0.0       0.54         1.0         0.80          0.0
# mnd           0.0     0.0       0.54         1.0         0.67          0.0
# nor           0.0     0.0       0.54         1.0         0.75          0.0
# pol           0.0     0.0       0.77         1.0         0.75          0.0
# por           0.0     0.0       0.00         1.0         0.25          0.0
# rom           0.0     0.0       0.67         1.0         0.50          0.0
# rus           0.0     0.0       0.77         1.0         0.40          0.0
# scr           0.0     0.0       0.00         1.0         1.00          0.0
# slo           0.0     0.0       0.00         1.0         1.00          0.0
# spa           0.0     0.0       0.62         1.0         0.25          0.0
# swa           0.0     0.0       0.77         0.0         0.40          0.0
# swe           0.0     0.0       0.00         1.0         0.50          0.0
# tel           1.0     1.0       1.00         1.0         1.00          0.0
# tha           0.0     0.0       0.62         0.0         0.80          0.0
# ukr           0.0     0.0       0.00         1.0         1.00          0.0
# vie           0.0     0.0       0.46         0.0         0.40          0.0
#
#      verbal_cat  wordorder  simple_clause  complex_sentences  lexicon  other  \
# ben        0.00       0.58           0.75                0.0      0.0    1.0
# bul        0.75       0.24           0.40                0.0      0.0    1.0
# ctl        0.40       0.22           0.00                0.0      1.0    0.0
# cze        0.33       0.40           0.80                0.0      0.0    0.0
# dsh        0.71       0.38           0.00                0.0      0.5    0.0
# dut        0.67       0.30           0.33                0.0      1.0    0.0
# eng        0.71       0.33           0.43                0.0      1.0    0.0
# fin        1.00       0.38           0.43                0.0      1.0    0.0
# fre        0.71       0.24           0.29                0.0      1.0    0.0
# ger        0.71       0.32           0.33                0.0      1.0    0.0
# hun        0.57       0.45           0.57                0.0      1.0    0.0
# ind        0.43       0.19           0.33                0.0      1.0    0.0
# ita        0.67       0.25           0.00                0.0      1.0    1.0
# jpn        0.43       0.92           0.43                0.0      0.5    0.0
# kor        0.43       0.68           0.43                0.0      0.5    0.0
# mnd        0.86       0.45           0.00                0.0      0.5    0.0
# nor        0.50       0.33           0.00                0.0      1.0    0.0
# pol        0.83       0.24           0.60                0.0      0.0    0.0
# por        0.67       0.22           0.00                0.0      0.0    0.0
# rom        0.67       0.24           0.40                0.0      0.0    0.0
# rus        0.71       0.29           0.57                0.0      0.5    0.0
# scr        0.67       0.33           0.40                0.0      0.0    1.0
# slo        0.67       0.33           0.00                0.0      0.0    0.0
# spa        0.86       0.24           0.14                0.0      1.0    0.0
# swa        0.29       0.20           0.43                0.0      0.5    0.0
# swe        0.71       0.38           0.40                0.0      1.0    0.0
# tel        1.00       1.00           1.00                0.0      1.0    1.0
# tha        0.71       0.14           0.14                0.0      0.5    0.0
# ukr        0.67       0.28           0.00                0.0      0.0    0.0
# vie        0.57       0.20           0.14                0.0      0.5    0.0
#
#      All features
# ben          0.64
# bul          0.42
# ctl          0.36
# cze          0.42
# dsh          0.44
# dut          0.38
# eng          0.46
# fin          0.57
# fre          0.37
# ger          0.43
# hun          0.53
# ind          0.41
# ita          0.34
# jpn          0.65
# kor          0.56
# mnd          0.47
# nor          0.43
# pol          0.50
# por          0.29
# rom          0.42
# rus          0.48
# scr          0.43
# slo          0.40
# spa          0.41
# swa          0.37
# swe          0.44
# tel          1.00
# tha          0.37
# ukr          0.33
# vie          0.31

# %%
df = get_distance_df(walsdata_test['wals_code'])

pairs = []
distances = []

for i in range(len(df)):
    for j in range(i+1, len(df)): 
        if df.iloc[i, j] != 0:

            pairs.append(f"{df.index[i]}-{df.columns[j]}")
            distances.append(df.iloc[i, j])

distance_pairs_df = pd.DataFrame({'Language pair': pairs, 'Distance': distances})
distance_pairs_df = distance_pairs_df.sort_values(by='Distance')
print(distance_pairs_df.head(10))
print(distance_pairs_df.tail(10))
